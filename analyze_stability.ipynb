# %%
import pandas as pd

df = pd.read_csv('experiment_tracker.csv')
print(df.head())
# Out:
#                     timestamp              experiment_name  \
# 0  2025-06-11T11:41:00.708578    batch_size_experiment_bs4
# 1  2025-06-11T13:02:55.915384    batch_size_experiment_bs8
# 2  2025-06-11T16:08:11.299700   batch_size_experiment_bs32
# 3  2025-06-12T09:01:02.239639   batch_size_experiment_bs64
# 4  2025-06-12T09:22:29.555845  batch_size_experiment_bs128
#
#                                              command  total_epochs  \
# 0  atomsurf/tasks/masif_site/train_hydra.py run_n...            50
# 1  atomsurf/tasks/masif_site/train_hydra.py run_n...            50
# 2  atomsurf/tasks/masif_site/train_hydra.py run_n...            50
# 3  atomsurf/tasks/masif_site/train_hydra.py run_n...            50
# 4  atomsurf/tasks/masif_site/train_hydra.py run_n...            50
#
#    final_train_loss  final_val_loss  final_test_loss  final_train_acc  \
# 0          0.615333        0.630301              NaN         0.591770
# ...

# %%
mean_cv,z_score_instability,mean_batch_zscore_instability
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 mean_cv,z_score_instability,mean_batch_zscore_instability
#
# NameError: name 'mean_cv' is not defined

# %%
summary = df.groupby('experiment_name')['mean_cv'].mean()
print(summary)
# Out:
# experiment_name
# batch_size_experiment_bs128                 0.012432
# batch_size_experiment_bs256                 0.008896
# batch_size_experiment_bs32                  0.023082
# batch_size_experiment_bs4                   0.049184
# batch_size_experiment_bs64                  0.016886
# batch_size_experiment_bs8                   0.039148
# full_dataset_batch_size_experiment_bs128    0.014283
# full_dataset_batch_size_experiment_bs16     0.034093
# full_dataset_batch_size_experiment_bs256    0.010089
# full_dataset_batch_size_experiment_bs32     0.026511
# full_dataset_batch_size_experiment_bs4      0.051627
# full_dataset_batch_size_experiment_bs64     0.019651
# full_dataset_batch_size_experiment_bs8      0.042018
# Name: mean_cv, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example: Boxplot of instability by batch size
sns.boxplot(x='batch_size', y='final_val_loss', data=df)
plt.xticks(rotation=90)
plt.title('Validation Loss by Batch Size')
plt.xlabel('Batch Size')
plt.savefig('instability_by_batch_size.png')  # Save for your slide
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example: Boxplot of instability by batch size
sns.boxplot(x='experiment_name', y='mean_cv', data=df)
plt.xticks(rotation=90)
plt.title('Mean CV by Batch Size')
plt.xlabel('Batch Size')
plt.savefig('instability_by_batch_size.png')  # Save for your slide
plt.show()
